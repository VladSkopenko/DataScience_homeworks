# %% [markdown]
# # Завдання №1
# Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv

# %%
import pandas as pd


data = pd.read_csv("2017_jun_final.csv")
data
# Out:
#          N                    Посада Мова програмування Спеціалізація  \
# 0        1        Junior QA engineer                NaN     Manual QA
# 1        2        Junior QA engineer                NaN     Manual QA
# 2        3         Software Engineer            C#/.NET           NaN
# 3        4         Software Engineer         JavaScript           NaN
# 4        5  Senior Software Engineer         JavaScript           NaN
# ...    ...                       ...                ...           ...
# 8699  8700               QA engineer                NaN     Manual QA
# 8700  8701                 Marketing                NaN           NaN
# 8701  8702  Junior Software Engineer         Ruby/Rails           NaN
# 8702  8703                 Team lead                NaN           NaN
# 8703  8704  Senior Software Engineer               Java           NaN
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                        0.5                              0.5
# ...

# %% [markdown]
# # Завдання №2
# Прочитайте отриману таблицю, використовуючи метод head

# %%
data.head()
# Out:
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# 0                 400                             0  Харків        до 10 осіб
# ...

# %% [markdown]
# # Завдання №3
# Визначте розмір таблиці за допомогою методу shape

# %%
data.shape
print(f"Кількість рядків: {data.shape[0]}\nКількість стопчиків: {data.shape[1]}")
# Out:
# Кількість рядків: 8704
# Кількість стопчиків: 25

# %% [markdown]
# # Завдання №4
# Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
data.dtypes
# Out:
# N                                     int64
# Посада                               object
# Мова програмування                   object
# Спеціалізація                        object
# Загальний досвід роботи              object
# Досвід роботи на поточному місці     object
# Зарплата на місяць                    int64
# Зміна зарплати за 12 місяців          int64
# Місто                                object
# Розмір компанії                      object
# Тип компанії                         object
# Стать                                object
# Вік                                   int64
# Освіта                               object
# Університет                          object
# Ще студент                             bool
# Рівень англійської                   object
# Предметна область                    object
# Дата заповнення                      object
# User.Agent                           object
# exp                                 float64
# ...

# %% [markdown]
# # Завдання №5
#
# Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
data.isnull().sum()
# Out:
# N                                      0
# Посада                                 0
# Мова програмування                  3850
# Спеціалізація                       7219
# Загальний досвід роботи                0
# Досвід роботи на поточному місці       0
# Зарплата на місяць                     0
# Зміна зарплати за 12 місяців           0
# Місто                                  0
# Розмір компанії                        0
# Тип компанії                           0
# Стать                                  0
# Вік                                    0
# Освіта                                 0
# Університет                          358
# Ще студент                             0
# Рівень англійської                     0
# Предметна область                    223
# Дата заповнення                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# ...

# %% [markdown]
# # Завдання №6
# Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"

# %%
cleaned_data = data.dropna(how="any",
                           subset=data.columns.difference(["Мова програмування"]))
cleaned_data
# Out:
#          N        Посада Мова програмування  Спеціалізація  \
# 3649  3650  QA Tech Lead                NaN  Automation QA
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 3649                       9                                3
#
#       Зарплата на місяць  Зміна зарплати за 12 місяців   Місто  \
# 3649                6000                           500  Дніпро
#
#      Розмір компанії  ... Ще студент       Рівень англійської  \
# 3649    до 1000 осіб  ...      False  Elementary (початковий)
#
#                  Предметна область      Дата заповнення  \
# 3649  Фінанси та банкінг,eCommerce  13/06/2017 22:22:50
#
#                                              User.Agent  exp current_job_exp  \
# 3649  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  9.0             3.0
#
#      salary Валюта cls
# 3649   6000      h  QA
#
# [1 rows x 25 columns]

# %% [markdown]
# # Завдання №7
# Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"

# %%
cleaned_data.isnull().sum()
# Out:
# N                                   0
# Посада                              0
# Мова програмування                  1
# Спеціалізація                       0
# Загальний досвід роботи             0
# Досвід роботи на поточному місці    0
# Зарплата на місяць                  0
# Зміна зарплати за 12 місяців        0
# Місто                               0
# Розмір компанії                     0
# Тип компанії                        0
# Стать                               0
# Вік                                 0
# Освіта                              0
# Університет                         0
# Ще студент                          0
# Рівень англійської                  0
# Предметна область                   0
# Дата заповнення                     0
# User.Agent                          0
# exp                                 0
# current_job_exp                     0
# salary                              0
# Валюта                              0
# cls                                 0
# ...

# %% [markdown]
# # Завдання №8
# Видаліть усі рядки у вихідній таблиці за допомогою методу dropna

# %%
data.dropna(inplace=True)

# %% [markdown]
# # Завдання №9
# Визначте новий розмір таблиці за допомогою методу shape

# %%
data.shape
# Out:
# (0, 25)

# %% [markdown]
# # Завдання №10
# Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python

# %%
data = pd.read_csv("2017_jun_final.csv")
python_data = data.loc[data['Мова програмування'] == 'Python']
python_data
# Out:
#          N                    Посада Мова програмування Спеціалізація  \
# 12      13         Software Engineer             Python           NaN
# 68      69         Software Engineer             Python           NaN
# 87      88  Junior Software Engineer             Python           NaN
# 114    115  Junior Software Engineer             Python           NaN
# 143    144  Junior Software Engineer             Python           NaN
# ...    ...                       ...                ...           ...
# 8546  8547         Software Engineer             Python           NaN
# 8625  8626         Software Engineer             Python           NaN
# 8635  8636  Senior Software Engineer             Python           NaN
# 8673  8674  Junior Software Engineer             Python           NaN
# 8695  8696         Software Engineer             Python           NaN
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 12                         1                  менше 3 місяців
# ...

# %% [markdown]
# # Завдання №11
# Визначте розмір таблиці python_data за допомогою методу shape

# %%
python_data.shape
# Out:
# (207, 25)

# %% [markdown]
# # Завдання № 12
# Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"

# %%
 grouped_data = python_data.groupby("Посада")
 grouped_data.first()
# Out:
#                              N Мова програмування Спеціалізація  \
# Посада
# Junior Software Engineer    88             Python          None
# Senior Software Engineer   303             Python          None
# Software Engineer           13             Python          None
# System Architect          5749             Python          None
# Technical Lead            2633             Python          None
#
#                          Загальний досвід роботи  \
# Посада
# Junior Software Engineer                     0.5
# Senior Software Engineer       10 і більше років
# Software Engineer                              1
# System Architect               10 і більше років
# Technical Lead                                 4
#
#                          Досвід роботи на поточному місці  Зарплата на місяць  \
# Посада
# Junior Software Engineer                              0.5                 600
# Senior Software Engineer                              0.5                3500
# ...

# %% [markdown]
# # Завдання №13
# Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"

# %%
agg_data = grouped_data.agg({"Зарплата на місяць": ["min", "max"]})
agg_data
# Out:
#                          Зарплата на місяць
#                                         min   max
# Посада
# Junior Software Engineer                100  1250
# Senior Software Engineer               1300  9200
# Software Engineer                       500  5400
# System Architect                       3000  5000
# Technical Lead                         1425  6200

# %% [markdown]
# # Завдання №14
# Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"

# %%
def fill_avg_salary(row):
    return row.mean()

agg_data['avg'] = agg_data['Зарплата на місяць'].apply(fill_avg_salary, axis=1)
agg_data
# Out:
#                          Зарплата на місяць           avg
#                                         min   max
# Посада
# Junior Software Engineer                100  1250   675.0
# Senior Software Engineer               1300  9200  5250.0
# Software Engineer                       500  5400  2950.0
# System Architect                       3000  5000  4000.0
# Technical Lead                         1425  6200  3812.5

# %% [markdown]
# # Завдання №15
# Створіть описову статистику за допомогою методу describe для нового стовпчика.

# %%
agg_data['avg'].describe()
# Out:
# count       5.000000
# mean     3337.500000
# std      1700.091909
# min       675.000000
# 25%      2950.000000
# 50%      3812.500000
# 75%      4000.000000
# max      5250.000000
# Name: avg, dtype: float64

# %% [markdown]
# # Завдання №16
# Збережіть отриману таблицю в CSV файл

# %%
agg_data.to_csv('data.csv', header=['min', 'max', 'avg'])
data = pd.read_csv('data.csv')
data
# Out:
#                      Посада   min   max     avg
# 0  Junior Software Engineer   100  1250   675.0
# 1  Senior Software Engineer  1300  9200  5250.0
# 2         Software Engineer   500  5400  2950.0
# 3          System Architect  3000  5000  4000.0
# 4            Technical Lead  1425  6200  3812.5

# %% [markdown]
# # Завдання №17

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url = "https://drive.google.com/file/d/1JMYqXipZpz9Y5-vyxvLEO2Y1sRBxqu-U/view"
url = "https://drive.google.com/uc?id=" + url.split("/")[-2]
df = pd.read_csv(url)
plt.title('Розподіл зарплат за гендерною ознакою')
sns.stripplot(data=df, x='Пол', y='Зарплата.в.месяц')
plt.show()

# %% [markdown]
# # Завдання №18

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler



df = pd.DataFrame(data)


scaler = MinMaxScaler()
df_normalized = pd.DataFrame(scaler.fit_transform(df.iloc[:, 1:]),
                              columns=['min', 'max', 'avg'])


df_normalized['Посада'] = df['Посада']


plt.figure(figsize=(10, 6))
pd.plotting.parallel_coordinates(df_normalized, 'Посада', colormap='viridis')
plt.title('Порівняння зарплатних пакетів різних посад')
plt.xlabel('Параметри зарплати')
plt.ylabel('Значення')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %% [markdown]
# # Завдання №19

# %%
python_data = df[df['Язык.программирования'] == 'Python'].copy()
data_pie=python_data['Должность'].value_counts()
plt.title('Розподіл Python програмістів за спеціалізацією')
plt.pie(
    data_pie,
    labels=data_pie.index,
    autopct="%.2f%%",
    explode=[0.05, 0.05, 0.05, 0.05, 0.05],
    shadow=True
)
plt.show()
